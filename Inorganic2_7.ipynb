# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
v_koh = np.arange(0, 8.5, 0.5)
pH1 = np.array([6.843,8.456,8.873,9.068,9.234,9.349,9.466,9.567,9.640,9.744,9.827,9.915,10,10.087,10.169,10.263,10.367])

d = {
    'V KOH': v_koh,
    'pH': pH1,
}
d = pd.DataFrame(d)
d
# Out:
#     V KOH      pH
# 0     0.0   6.843
# 1     0.5   8.456
# 2     1.0   8.873
# 3     1.5   9.068
# 4     2.0   9.234
# 5     2.5   9.349
# 6     3.0   9.466
# 7     3.5   9.567
# 8     4.0   9.640
# 9     4.5   9.744
# 10    5.0   9.827
# 11    5.5   9.915
# 12    6.0  10.000
# 13    6.5  10.087
# 14    7.0  10.169
# 15    7.5  10.263
# 16    8.0  10.367

# %%
H = np.power(10, -pH1)
K = (v_koh * 0.5) / (200 + v_koh)
OH = (pow(10, -14) / H)
A = K
At = (10 * 0.4) / (200 + v_koh)  
HA = At - A
HA2 = At - (K + H - OH)


pka = pH1 + np.log10(HA/(K + H - OH))
ka = pow(10, -pka)

data1 = {
    'V KOH': v_koh,
    'pH': pH1,
    '[H]': H,
    '[K]': K,
    '[OH]': OH,
    '[A]': A,
    '[HA]': HA,
    'pKa': pka,
    'Ka': ka,
}

data1 = pd.DataFrame(data1)
data1
# Out:
# C:\Users\Hossein\AppData\Local\Temp\ipykernel_13736\2367613059.py:10: RuntimeWarning: divide by zero encountered in log10
#   pka = pH1 + np.log10(HA/(K + H - OH))
#     V KOH      pH           [H]       [K]          [OH]       [A]      [HA]  \
# 0     0.0   6.843  1.435489e-07  0.000000  6.966265e-08  0.000000  0.020000
# 1     0.5   8.456  3.499452e-09  0.001247  2.857591e-06  0.001247  0.018703
# 2     1.0   8.873  1.339677e-09  0.002488  7.464488e-06  0.002488  0.017413
# 3     1.5   9.068  8.550667e-10  0.003722  1.169499e-05  0.003722  0.016129
# 4     2.0   9.234  5.834451e-10  0.004950  1.713957e-05  0.004950  0.014851
# 5     2.5   9.349  4.477133e-10  0.006173  2.233572e-05  0.006173  0.013580
# 6     3.0   9.466  3.419794e-10  0.007389  2.924152e-05  0.007389  0.012315
# 7     3.5   9.567  2.710192e-10  0.008600  3.689776e-05  0.008600  0.011057
# 8     4.0   9.640  2.290868e-10  0.009804  4.365158e-05  0.009804  0.009804
# 9     4.5   9.744  1.803018e-10  0.011002  5.546257e-05  0.011002  0.008557
# 10    5.0   9.827  1.489361e-10  0.012195  6.714289e-05  0.012195  0.007317
# 11    5.5   9.915  1.216186e-10  0.013382  8.222426e-05  0.013382  0.006083
# 12    6.0  10.000  1.000000e-10  0.014563  1.000000e-04  0.014563  0.004854
# 13    6.5  10.087  8.184648e-11  0.015738  1.221800e-04  0.015738  0.003632
# 14    7.0  10.169  6.776415e-11  0.016908  1.475707e-04  0.016908  0.002415
# 15    7.5  10.263  5.457579e-11  0.018072  1.832314e-04  0.018072  0.001205
# 16    8.0  10.367  4.295364e-11  0.019231  2.328091e-04  0.019231  0.000000
#
#           pKa            Ka
# 0   12.275466  5.303150e-13
# 1    9.633086  2.327628e-10
# 2    9.719403  1.908082e-10
# 3    9.706189  1.967031e-10
# 4    9.712627  1.938084e-10
# 5    9.692997  2.027697e-10
# 6    9.689571  2.043757e-10
# 7    9.678012  2.098882e-10
# 8    9.641938  2.280668e-10
# 9    9.637050  2.306480e-10
# 10   9.607549  2.468602e-10
# 11   9.575254  2.659169e-10
# 12   9.525871  2.979400e-10
# 13   9.453563  3.519147e-10
# 14   9.327709  4.702091e-10
# 15   9.091334  8.103368e-10
# 16       -inf           inf

# %%
# print(np.log10(HA/A))

# %%
print(ka[4:13])
Ka = np.mean(ka[4:13])
# print(Ka)
# print(-np.log10(Ka))
# Out:
# [1.93808391e-10 2.02769698e-10 2.04375675e-10 2.09888245e-10
#  2.28066771e-10 2.30647999e-10 2.46860183e-10 2.65916923e-10
#  2.97940002e-10]

# %%
plt.plot(v_koh, pH1)
plt.title('Titration plot of Glycinate')
plt.xlabel('Volume of KOH')
plt.ylabel('pH')
plt.show()

# %%
v = np.arange(0, 10.2, 0.2)
pH2 = np.array([2.327,2.343,2.384,2.395,2.413,2.430,2.450,2.463,2.480,2.501,2.558,
               2.578,2.593,2.602,2.612,2.621,2.631,2.641,2.649,2.658,2.668,
              2.677,2.686,2.697,2.712,2.721,2.729,2.738,2.746,2.753,2.762,
              2.770,2.778,2.786,2.791,2.800,2.806,2.814,2.821,2.828,2.834,
              2.841,2.848,2.858,2.868,2.878,2.884,2.890,2.896,2.903,2.908])

d2 = {
    'V_Gly': v,
    'pH': pH2,
}

d2 = pd.DataFrame(d2)
d2
# Out:
#     V_Gly     pH
# 0     0.0  2.327
# 1     0.2  2.343
# 2     0.4  2.384
# 3     0.6  2.395
# 4     0.8  2.413
# 5     1.0  2.430
# 6     1.2  2.450
# 7     1.4  2.463
# 8     1.6  2.480
# 9     1.8  2.501
# 10    2.0  2.558
# 11    2.2  2.578
# 12    2.4  2.593
# 13    2.6  2.602
# 14    2.8  2.612
# 15    3.0  2.621
# 16    3.2  2.631
# 17    3.4  2.641
# 18    3.6  2.649
# 19    3.8  2.658
# 20    4.0  2.668
# 21    4.2  2.677
# 22    4.4  2.686
# 23    4.6  2.697
# 24    4.8  2.712
# 25    5.0  2.721
# 26    5.2  2.729
# 27    5.4  2.738
# 28    5.6  2.746
# 29    5.8  2.753
# 30    6.0  2.762
# 31    6.2  2.770
# 32    6.4  2.778
# 33    6.6  2.786
# 34    6.8  2.791
# 35    7.0  2.800
# 36    7.2  2.806
# 37    7.4  2.814
# 38    7.6  2.821
# 39    7.8  2.828
# 40    8.0  2.834
# 41    8.2  2.841
# 42    8.4  2.848
# 43    8.6  2.858
# 44    8.8  2.868
# 45    9.0  2.878
# 46    9.2  2.884
# 47    9.4  2.890
# 48    9.6  2.896
# 49    9.8  2.903
# 50   10.0  2.908

# %%
H = np.power(10, -pH2)
OH = (pow(10, -14) / H)
CH = (10 * 0.1) / (200 + v)
A = (Ka * (CH + OH - H)) / H
Mt = 1 / (200 + v)

At = (v * 0.4) / (200 + v)

n = (At - ((1 + Ka/H) * (CH + OH - H))) / Mt
# n

# %%
data2 = {
    'V Gly': v,
    'pH': pH2,
    '[H]': H,
    '[OH]': OH,
    '[A]': A,
    '[CH]': CH,
    '[Mtot]': Mt,
    'n': n,
}

data2 = pd.DataFrame(data2)
data2
# Out:
#     V Gly     pH       [H]          [OH]           [A]      [CH]    [Mtot]  \
# 0     0.0  2.327  0.004710  2.123244e-12  1.424346e-11  0.005000  0.005000
# 1     0.2  2.343  0.004539  2.202926e-12  2.319803e-11  0.004995  0.004995
# 2     0.4  2.384  0.004130  2.421029e-12  4.810017e-11  0.004990  0.004990
# 3     0.6  2.395  0.004027  2.483133e-12  5.497771e-11  0.004985  0.004985
# 4     0.8  2.413  0.003864  2.588213e-12  6.678850e-11  0.004980  0.004980
# 5     1.0  2.430  0.003715  2.691535e-12  7.837364e-11  0.004975  0.004975
# 6     1.2  2.450  0.003548  2.818383e-12  9.263847e-11  0.004970  0.004970
# 7     1.4  2.463  0.003443  2.904023e-12  1.021456e-10  0.004965  0.004965
# 8     1.6  2.480  0.003311  3.019952e-12  1.151066e-10  0.004960  0.004960
# 9     1.8  2.501  0.003155  3.169567e-12  1.319004e-10  0.004955  0.004955
# 10    2.0  2.558  0.002767  3.614099e-12  1.824071e-10  0.004950  0.004950
# 11    2.2  2.578  0.002642  3.784426e-12  2.014688e-10  0.004946  0.004946
# 12    2.4  2.593  0.002553  3.917419e-12  2.162291e-10  0.004941  0.004941
# 13    2.6  2.602  0.002500  3.999447e-12  2.251460e-10  0.004936  0.004936
# 14    2.8  2.612  0.002443  4.092607e-12  2.353138e-10  0.004931  0.004931
# 15    3.0  2.621  0.002393  4.178304e-12  2.446119e-10  0.004926  0.004926
# 16    3.2  2.631  0.002339  4.275629e-12  2.552145e-10  0.004921  0.004921
# 17    3.4  2.641  0.002286  4.375221e-12  2.660538e-10  0.004916  0.004916
# 18    3.6  2.649  0.002244  4.456562e-12  2.747999e-10  0.004912  0.004912
# 19    3.8  2.658  0.002198  4.549881e-12  2.848871e-10  0.004907  0.004907
# 20    4.0  2.668  0.002148  4.655861e-12  2.963893e-10  0.004902  0.004902
# 21    4.2  2.677  0.002104  4.753352e-12  3.069080e-10  0.004897  0.004897
# 22    4.4  2.686  0.002061  4.852885e-12  3.176370e-10  0.004892  0.004892
# 23    4.6  2.697  0.002009  4.977371e-12  3.311640e-10  0.004888  0.004888
# 24    4.8  2.712  0.001941  5.152286e-12  3.503562e-10  0.004883  0.004883
# 25    5.0  2.721  0.001901  5.260173e-12  3.619533e-10  0.004878  0.004878
# 26    5.2  2.729  0.001866  5.357967e-12  3.723909e-10  0.004873  0.004873
# 27    5.4  2.738  0.001828  5.470160e-12  3.844286e-10  0.004869  0.004869
# 28    5.6  2.746  0.001795  5.571857e-12  3.952630e-10  0.004864  0.004864
# 29    5.8  2.753  0.001766  5.662393e-12  4.048226e-10  0.004859  0.004859
# 30    6.0  2.762  0.001730  5.780960e-12  4.175090e-10  0.004854  0.004854
# 31    6.2  2.770  0.001698  5.888437e-12  4.289275e-10  0.004850  0.004850
# 32    6.4  2.778  0.001667  5.997911e-12  4.405476e-10  0.004845  0.004845
# 33    6.6  2.786  0.001637  6.109420e-12  4.523729e-10  0.004840  0.004840
# 34    6.8  2.791  0.001618  6.180164e-12  4.596189e-10  0.004836  0.004836
# 35    7.0  2.800  0.001585  6.309573e-12  4.734017e-10  0.004831  0.004831
# 36    7.2  2.806  0.001563  6.397348e-12  4.825134e-10  0.004826  0.004826
# 37    7.4  2.814  0.001535  6.516284e-12  4.950802e-10  0.004822  0.004822
# 38    7.6  2.821  0.001510  6.622165e-12  5.061694e-10  0.004817  0.004817
# 39    7.8  2.828  0.001486  6.729767e-12  5.174285e-10  0.004812  0.004812
# 40    8.0  2.834  0.001466  6.823387e-12  5.271124e-10  0.004808  0.004808
# 41    8.2  2.841  0.001442  6.934258e-12  5.386928e-10  0.004803  0.004803
# 42    8.4  2.848  0.001419  7.046931e-12  5.504508e-10  0.004798  0.004798
# 43    8.6  2.858  0.001387  7.211075e-12  5.678896e-10  0.004794  0.004794
# 44    8.8  2.868  0.001355  7.379042e-12  5.857182e-10  0.004789  0.004789
# 45    9.0  2.878  0.001324  7.550922e-12  6.039455e-10  0.004785  0.004785
# 46    9.2  2.884  0.001306  7.655966e-12  6.147532e-10  0.004780  0.004780
# 47    9.4  2.890  0.001288  7.762471e-12  6.257016e-10  0.004776  0.004776
# 48    9.6  2.896  0.001271  7.870458e-12  6.367925e-10  0.004771  0.004771
# 49    9.8  2.903  0.001250  7.998343e-12  6.500545e-10  0.004766  0.004766
# 50   10.0  2.908  0.001236  8.090959e-12  6.594093e-10  0.004762  0.004762
#
#            n
# 0  -0.058045
# 1  -0.011209
# 2  -0.012253
# 3   0.047850
# 4   0.095825
# 5   0.146786
# 6   0.193885
# 7   0.253521
# 8   0.307560
# 9   0.356680
# 10  0.358922
# 11  0.414295
# 12  0.476667
# 13  0.546570
# 14  0.615528
# 15  0.685843
# 16  0.755252
# 17  0.824891
# 18  0.896854
# 19  0.967924
# 20  1.038157
# 21  1.109591
# 22  1.181193
# 23  1.251060
# 24  1.317493
# 25  1.389721
# 26  1.462981
# 27  1.535492
# 28  1.608997
# 29  1.683450
# 30  1.756342
# 31  1.830178
# 32  1.904120
# 33  1.978166
# 34  2.054619
# 35  2.128073
# 36  2.203884
# 37  2.278279
# 38  2.353493
# 39  2.428777
# 40  2.504834
# 41  2.580248
# 42  2.655731
# 43  2.729277
# 44  2.802963
# 45  2.876787
# 46  2.953251
# 47  3.029759
# 48  3.106312
# 49  3.182304
# 50  3.259549

# %%
plt.plot(np.log10(A), n)
plt.xlabel('log([A])')
plt.ylabel('n')
plt.grid()
plt.show()

# %%
# np.log10(A)
